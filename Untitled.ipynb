# %%
import base64

# %%
s = '...'

# %%
type(s)
# Out:
# str

# %%
bs = bytes(s,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-e5c0d1079914> in <module>
# ----> 1 bs = bytes(s)
#
# TypeError: string argument without an encoding

# %%
type(bs)
# Out:
# bytes

# %%
with open(f"img.png", "wb") as fh:
    fh.write(base64.decodebytes(bs))
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-16-a35b5afdef5b> in <module>
#       1 with open(f"img.png", "wb") as fh:
# ----> 2     fh.write(base64.decodebytes(bs))
#
# ~/anaconda3/lib/python3.7/base64.py in decodebytes(s)
#     544     """Decode a bytestring of base-64 data into a bytes object."""
#     545     _input_type_check(s)
# --> 546     return binascii.a2b_base64(s)
#     547
#     548 def decodestring(s):
#
# Error: Invalid base64-encoded string: number of data characters (1) cannot be 1 more than a multiple of 4
